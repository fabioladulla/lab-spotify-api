# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import time
from credentialz import *

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_secret))

# %%
def search_song(title, artist):
    
    query = "tracks: "+title+" artist: "+artist
    #print(query)

    try:
        result = sp.search(query, limit=1)
        song_id = result['tracks']['items'][0]['id']
    except:
        song_id = "not_found"

    return song_id

# %%
search_song("Hello", "Adele")
# Out:
# '1AynHbA5tcynFDplpCY5lz'

# %%
df1 = pd.read_csv('/Users/durimferati/Desktop/IRONHACK/Week_6/Day_1/Morning/lab-web-scraping-single-page/hot100.csv')
df2 = pd.read_csv('/Users/durimferati/Desktop/IRONHACK/Week_6/Day_1/Afternoon/lab-not-hot-songs/not_hot100.csv')
df2.isnull().sum()
# Out:
# Artist    0
# Title     1
# dtype: int64

# %%
df2 = df2.drop(65)

# %%
# create groups for 50 song for df1 and df2
chunks_df1 = [df1.iloc[i:i+50] for i in range(0, len(df1), 50)]

# %%
# create groups fo 50 song for df1
chunks_df2 = [df2[i:i + 50] for i in range(0, len(df2), 50)]

# %%
#create the list of id's of df1
song_ids_df1 = []
for chunk in chunks_df1:
    for index, row in chunk.iterrows():
        song_id = search_song(row["Title"], row["Artist"])
        song_ids_df1.append(song_id)
    time.sleep(20)
print('finished')
# Out:
# finished

# %%
#create the list of id's of df2
song_ids_df2 = []
for chunk in chunks_df2:
    for index, row in chunk.iterrows():
        song_id = search_song(row["Title"], row["Artist"])
        song_ids_df2.append(song_id)
    time.sleep(20)
print('finished')
# Out:
# finished

# %%
len(song_ids_df1)
# Out:
# 100

# %%
 def get_audio_features(list_of_song_ids):
    
    chunks = [list_of_song_ids[i:i + 50] for i in range(0, len(list_of_song_ids), 50)]
    
    # Create a dictionary to store the audio features
    audio_features_dict = {
        'id': [],
        'energy': [],
        'key': [],
        'acousticness': [],
        'instrumentalness': [],
        'liveness': [],
        'tempo': [],
        'type': [],
        'uri': [],
        'track_href': [],
        'analysis_url': [],
        'duration_ms': [],
    }
    
    # Retrieve the audio features for each chunk
    for chunk in chunks:
        audio_features = sp.audio_features(chunk)
        
        # Append the audio features to the dictionary
        for feature in audio_features:
            if feature:
                for key in audio_features_dict.keys():
                    audio_features_dict[key].append(feature[key])
        
        # Wait 20 seconds before next API call
        time.sleep(20)

    # Create a DataFrame from the dictionary
    df = pd.DataFrame(audio_features_dict)

    return df

# %%
df3 = get_audio_features(song_ids_df1)
len(df3)
# Out:
# 100

# %%
results_hot100 = pd.concat([df1, df3], axis=1)
results_hot100.head()
# Out:
#                 Artist       Title                      id  energy  key  \
# 0       Olivia Rodrigo     Vampire  4sSKTQcX6pQIncWcNJdkiD   0.609    1
# 1        Morgan Wallen  Last Night  59uQI0PADDKeE6UZDTJEe8   0.675    6
# 2           Luke Combs    Fast Car  2M9ro2krNb7nr7HSprkEgo   0.292    4
# 3  Rema & Selena Gomez   Calm Down  0WtM2NBVQNNJLh6scP13H8   0.806   11
# 4          Miley Cyrus     Flowers  4DHcnVTT87F0zZhRPYmZ3B   0.681    0
#
#    acousticness  instrumentalness  liveness    tempo            type  \
# 0        0.2840          0.268000    0.1120  119.973  audio_features
# 1        0.4590          0.000000    0.1510  203.853  audio_features
# 2        0.3130          0.000000    0.1310  103.951  audio_features
# 3        0.3820          0.000669    0.1140  106.999  audio_features
# 4        0.0632          0.000005    0.0322  117.999  audio_features
#
#                                     uri  \
# 0  spotify:track:4sSKTQcX6pQIncWcNJdkiD
# 1  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 2  spotify:track:2M9ro2krNb7nr7HSprkEgo
# 3  spotify:track:0WtM2NBVQNNJLh6scP13H8
# 4  spotify:track:4DHcnVTT87F0zZhRPYmZ3B
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4sSKTQcX6pQI...
# 1  https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 2  https://api.spotify.com/v1/tracks/2M9ro2krNb7n...
# 3  https://api.spotify.com/v1/tracks/0WtM2NBVQNNJ...
# 4  https://api.spotify.com/v1/tracks/4DHcnVTT87F0...
#
#                                         analysis_url  duration_ms
# 0  https://api.spotify.com/v1/audio-analysis/4sSK...       300000
# 1  https://api.spotify.com/v1/audio-analysis/59uQ...       163855
# 2  https://api.spotify.com/v1/audio-analysis/2M9r...       296800
# 3  https://api.spotify.com/v1/audio-analysis/0WtM...       239318
# 4  https://api.spotify.com/v1/audio-analysis/4DHc...       200455

# %%
results_hot100.to_csv('results_hot100.csv', index=False)

# %%
len(song_ids_df2)
# Out:
# 2499

# %%
#to get the index which has 'not_found'
index_list = []
for i in range(0,2499):
    if song_ids_df2[i] == 'not_found':
        index_list.append(i)
index_list

# %%
list_of_valid_id = []
for x in song_ids_df2:
    if x != 'not_found':
        list_of_valid_id.append(x)
song_ids_df2 = list_of_valid_id

# %%
len(song_ids_df2)
# Out:
# 2489

# %%
df4 = get_audio_features(song_ids_df2)

# %%
df4.shape
# Out:
# (2489, 12)

# %%
results_nothot100 = pd.concat([df2, df4], axis=1)
results_nothot100
# Out:
#                 Artist                         Title                      id  \
# 0          NLE Choppa                    Shotta Flow  5BJMeoCXXgbRAWfp6fTulr
# 1     Jennifer Ormond                    Without You  7IfbF3rQlQ5coHkXS4Casy
# 2     Quality Control   Baby (Lil Baby feat. DaBaby)  5MPPttjfGap2C6j6eKcO6J
# 3                Kygo                       Carry Me  4Szq4dulKN9bOvLRW6uMdZ
# 4        Lil Uzi Vert                           Two®  627hYjsCXaPAUmQFiocDGF
# ...                ...                           ...                     ...
# 2496         Rod Wave                 Invisible Scar                     NaN
# 2497         A$AP Mob                      Perry Aye                     NaN
# 2498     Benson Boone                   In The Stars                     NaN
# 2499     Jack Garratt                      Weathered                     NaN
# 65                 NaN                           NaN  0rOP1naZV8zL7ahMNTDXhL
#
#       energy   key  acousticness  instrumentalness  liveness    tempo  \
# 0      0.511   2.0      0.025100             0.000    0.1400  120.077
# 1      0.879   3.0      0.058300             0.000    0.1440  110.940
# 2      0.463  10.0      0.095700             0.000    0.1510  108.003
# 3      0.713   4.0      0.011700             0.150    0.0952  119.997
# 4      0.738   7.0      0.421000             0.000    0.0860  142.770
# ...      ...   ...           ...               ...       ...      ...
# 2496     NaN   NaN           NaN               NaN       NaN      NaN
# 2497     NaN   NaN           NaN               NaN       NaN      NaN
# 2498     NaN   NaN           NaN               NaN       NaN      NaN
# 2499     NaN   NaN           NaN               NaN       NaN      NaN
# 65     0.780   7.0      0.000135             0.301    0.1110  120.122
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:5BJMeoCXXgbRAWfp6fTulr
# 1     audio_features  spotify:track:7IfbF3rQlQ5coHkXS4Casy
# 2     audio_features  spotify:track:5MPPttjfGap2C6j6eKcO6J
# 3     audio_features  spotify:track:4Szq4dulKN9bOvLRW6uMdZ
# 4     audio_features  spotify:track:627hYjsCXaPAUmQFiocDGF
# ...              ...                                   ...
# 2496             NaN                                   NaN
# 2497             NaN                                   NaN
# 2498             NaN                                   NaN
# 2499             NaN                                   NaN
# 65    audio_features  spotify:track:0rOP1naZV8zL7ahMNTDXhL
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5BJMeoCXXgbR...
# 1     https://api.spotify.com/v1/tracks/7IfbF3rQlQ5c...
# 2     https://api.spotify.com/v1/tracks/5MPPttjfGap2...
# 3     https://api.spotify.com/v1/tracks/4Szq4dulKN9b...
# 4     https://api.spotify.com/v1/tracks/627hYjsCXaPA...
# ...                                                 ...
# 2496                                                NaN
# 2497                                                NaN
# 2498                                                NaN
# 2499                                                NaN
# 65    https://api.spotify.com/v1/tracks/0rOP1naZV8zL...
#
#                                            analysis_url  duration_ms
# 0     https://api.spotify.com/v1/audio-analysis/5BJM...     176632.0
# 1     https://api.spotify.com/v1/audio-analysis/7Ifb...     178707.0
# 2     https://api.spotify.com/v1/audio-analysis/5MPP...     142417.0
# 3     https://api.spotify.com/v1/audio-analysis/4Szq...     159133.0
# 4     https://api.spotify.com/v1/audio-analysis/627h...     185276.0
# ...                                                 ...          ...
# 2496                                                NaN          NaN
# 2497                                                NaN          NaN
# 2498                                                NaN          NaN
# 2499                                                NaN          NaN
# 65    https://api.spotify.com/v1/audio-analysis/0rOP...     259253.0
#
# [2500 rows x 14 columns]

# %%
results_nothot100.dropna(subset=['id'], inplace=True)
results_nothot100
# Out:
#                 Artist                         Title                      id  \
# 0          NLE Choppa                    Shotta Flow  5BJMeoCXXgbRAWfp6fTulr
# 1     Jennifer Ormond                    Without You  7IfbF3rQlQ5coHkXS4Casy
# 2     Quality Control   Baby (Lil Baby feat. DaBaby)  5MPPttjfGap2C6j6eKcO6J
# 3                Kygo                       Carry Me  4Szq4dulKN9bOvLRW6uMdZ
# 4        Lil Uzi Vert                           Two®  627hYjsCXaPAUmQFiocDGF
# ...                ...                           ...                     ...
# 2485            Wisin                    Fiel  Remix  05x3RtkCoDNjvLq2bwLNwJ
# 2486          Cardi B                          Money  0PDwNx6GrHc5sRVy6Hc7GP
# 2487  Earl Sweatshirt                       The Mint  1bbASeaACA1Nx14lEHD8DX
# 2488     Thomas Rhett       What’s Your Country Song  62n7DLmd6yh8MlaxamIb2t
# 65                 NaN                           NaN  0rOP1naZV8zL7ahMNTDXhL
#
#       energy   key  acousticness  instrumentalness  liveness    tempo  \
# 0      0.511   2.0      0.025100          0.000000    0.1400  120.077
# 1      0.879   3.0      0.058300          0.000000    0.1440  110.940
# 2      0.463  10.0      0.095700          0.000000    0.1510  108.003
# 3      0.713   4.0      0.011700          0.150000    0.0952  119.997
# 4      0.738   7.0      0.421000          0.000000    0.0860  142.770
# ...      ...   ...           ...               ...       ...      ...
# 2485   0.584  11.0      0.163000          0.000000    0.0717  116.975
# 2486   0.535   5.0      0.048300          0.000000    0.1020  117.957
# 2487   0.540  10.0      0.338000          0.000000    0.1390   78.007
# 2488   0.496   0.0      0.094500          0.000114    0.0838  140.828
# 65     0.780   7.0      0.000135          0.301000    0.1110  120.122
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:5BJMeoCXXgbRAWfp6fTulr
# 1     audio_features  spotify:track:7IfbF3rQlQ5coHkXS4Casy
# 2     audio_features  spotify:track:5MPPttjfGap2C6j6eKcO6J
# 3     audio_features  spotify:track:4Szq4dulKN9bOvLRW6uMdZ
# 4     audio_features  spotify:track:627hYjsCXaPAUmQFiocDGF
# ...              ...                                   ...
# 2485  audio_features  spotify:track:05x3RtkCoDNjvLq2bwLNwJ
# 2486  audio_features  spotify:track:0PDwNx6GrHc5sRVy6Hc7GP
# 2487  audio_features  spotify:track:1bbASeaACA1Nx14lEHD8DX
# 2488  audio_features  spotify:track:62n7DLmd6yh8MlaxamIb2t
# 65    audio_features  spotify:track:0rOP1naZV8zL7ahMNTDXhL
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5BJMeoCXXgbR...
# 1     https://api.spotify.com/v1/tracks/7IfbF3rQlQ5c...
# 2     https://api.spotify.com/v1/tracks/5MPPttjfGap2...
# 3     https://api.spotify.com/v1/tracks/4Szq4dulKN9b...
# 4     https://api.spotify.com/v1/tracks/627hYjsCXaPA...
# ...                                                 ...
# 2485  https://api.spotify.com/v1/tracks/05x3RtkCoDNj...
# 2486  https://api.spotify.com/v1/tracks/0PDwNx6GrHc5...
# 2487  https://api.spotify.com/v1/tracks/1bbASeaACA1N...
# 2488  https://api.spotify.com/v1/tracks/62n7DLmd6yh8...
# 65    https://api.spotify.com/v1/tracks/0rOP1naZV8zL...
#
#                                            analysis_url  duration_ms
# 0     https://api.spotify.com/v1/audio-analysis/5BJM...     176632.0
# 1     https://api.spotify.com/v1/audio-analysis/7Ifb...     178707.0
# 2     https://api.spotify.com/v1/audio-analysis/5MPP...     142417.0
# 3     https://api.spotify.com/v1/audio-analysis/4Szq...     159133.0
# 4     https://api.spotify.com/v1/audio-analysis/627h...     185276.0
# ...                                                 ...          ...
# 2485  https://api.spotify.com/v1/audio-analysis/05x3...     168205.0
# 2486  https://api.spotify.com/v1/audio-analysis/0PDw...     146427.0
# 2487  https://api.spotify.com/v1/audio-analysis/1bbA...     216410.0
# 2488  https://api.spotify.com/v1/audio-analysis/62n7...     274693.0
# 65    https://api.spotify.com/v1/audio-analysis/0rOP...     259253.0
#
# [2489 rows x 14 columns]

# %%
results_nothot100.to_csv('results_nothot100.csv', index=False)
